# %% [markdown]
# ## Project: Build a Traffic Sign Recognition Program
# ---
# In this project, I will use what I've learned about deep neural networks and convolutional neural networks to classify traffic signs. I will train and validate a model so it can classify traffic sign images using the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset). After the model is trained, I will then try out my model on five images of German traffic signs that I found on the web.
#
#
# The specifications for this project are to submit the following three files:
# * the Ipython notebook with the code
# * the code exported as an html file
# * a writeup report either as a markdown or pdf file
#
#
# The Project
# ---
# The goals / steps of this project are the following:
# * Load the data set
# * Explore, summarize and visualize the data set
# * Design, train and test a model architecture
# * Use the model to make predictions on new images
# * Analyze the softmax probabilities of the new images
# * Summarize the results with a written report
#
# [//]: # (Image References)
#
# [image1]: ./German_Traffic_Sign_1.jpg
# [image2]: ./German_Traffic_Sign_2.jpg
# [image3]: ./German_Traffic_Sign_3.jpg
# [image4]: ./German_Traffic_Sign_4.jpg
# [image5]: ./German_Traffic_Sign_5.jpg
# [image6]: ./processed_image.jpg
#
# ## Rubric Points
# ###Here I will consider the [rubric points](https://review.udacity.com/#!/rubrics/481/view) individually and describe how I addressed each point in my implementation.
#
# ---
#
# ###Data Set Summary & Exploration
#
# ####1. Provide a basic summary of the data set. In the code, the analysis should be done using python, numpy and/or pandas methods rather than hardcoding results manually.
#
# The data set is a group of German Traffic signs that are labeled.  In total there are 43 different types of german traffic sign.  I utilized the traffic sign classifier and standard python procedures to analyze the results of the classifier.
#
# ####2. Include an exploratory visualization of the dataset.
#
#
# ![alt text][image1]
# ![alt text][image2]
# ![alt text][image3]
# ![alt text][image4]
# ![alt text][image5]
#
# ###Design and Test a Model Architecture
#
# ####1. Describe how you preprocessed the image data. What techniques were chosen and why did you choose these techniques? Consider including images showing the output of each preprocessing technique. Pre-processing refers to techniques such as converting to grayscale, normalization, etc. (OPTIONAL: As described in the "Stand Out Suggestions" part of the rubric, if you generated additional data for training, describe why you decided to generate additional data, how you generated the data, and provide example images of the additional data. Then describe the characteristics of the augmented training set like number of images in the set, number of images for each class, etc.)
#
# As a first step, I cropped the images with the microsoft software point to get just the image of the sign itself and remove a lot of the background and additional signs in the images.   Then I proceeded to convert the images to a height and width of 32x32 pixels, while maintaining the three color channels.
#
# Here is an example of a traffic sign image before processing:
#
# ![alt text][image5]
#
# I wanted the classifier to be able to identify images of poor quality and signs that might be small in size within the image, which equates to less pixel representation of the image.  This is what the image looks like after processing:
#
# ![alt text][image6]
#
#
# ####2. Describe what your final model architecture looks like including model type, layers, layer sizes, connectivity, etc.) Consider including a diagram and/or table describing the final model.
#
# My final model consisted of the following layers:
#
# | Layer                 |  Description        |
# |:---------------------:|:-------------------:|
# | Input                 | 32x32x3 RGB image    |
# | Convolution 3x3       | 1x1 stride, same padding,outputs 28x28x6 |
# | RELU                  | activation function  |
# | Max pooling           | 2x2 stride, outputs 14x14x6     |
# | Convolution 3x3       | 1x1 stride, same padding,outputs 10x10x16 |
# | Relu                  | activation function  |
# | Max pooling           | 2x2 stride, outputs 5x5x6     |
# | Flatten               |  Flatten array into an output of 5x5x6 = 400 |
# | Fully connected       | Input =400, Output =120 |
# | Relu | activation function |
# | Fully connected       | Input = 120, Output = 84 |
# | Relu  | activation function |
# | Fully connected       | Input = 84, Output = 43 |
#
#
# ####3. Describe how you trained your model. The discussion can include the type of optimizer, the batch size, number of epochs and any hyperparameters such as learning rate.
#
# In order to train the model I utilized a batch size of 128, 10 epochs, and a learning rate of 0.001.  With these parameters I passed the results of training into the adam optimizer.
#
# ####4. Describe the approach taken for finding a solution and getting the validation set accuracy to be at least 0.93. Include in the discussion the results on the training, validation and test sets and where in the code these were calculated. Your approach may have been an iterative process, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think the architecture is suitable for the current problem.
#
# My final model results were:
# * validation set accuracy of 94%
# * test set accuracy of 86%
#
# If a well known architecture was chosen:
# * I utilized the LeNet architecture for this traffic sign classifier
# * I thought that LeNet would be a good fit because the previous examples in lectures showed the LeNet classifier idnetifying image shapes and colors very well.
# * The models validation accuracy and test accuracy illustrate that the model is a decent fit for identifying traffic signs; however, the model can still use some improvements like dropout being incorporated into the model to help the model generalize better and prevent the system from over fitting.
#
#
# ###Test a Model on New Images
#
# ####1. Choose five German traffic signs found on the web and provide them in the report. For each image, discuss what quality or qualities might be difficult to classify.
#
# Here are five German traffic signs that I found on the web:
#
# ![alt text][image1] ![alt text][image2] ![alt text][image3]
# ![alt text][image4] ![alt text][image5]
#
# The first image might be difficult to classify because it is just a white arrow on a blue background and there are several white arrows on blue backgrounds in the data set that it could be easily mixed up with.
#
# The second image might be difficult to classify because the zero in the number 30 might get mixed up with the zeros in any of the other speed limit signs because they all have zeros in them and in addition they all have the same colors.
#
# The third image shouldn't be to difficult to classify this one should be pretty easy.  There are no other images with the same center symbol on the sign.
#
# The fourth image may be difficult to classify because the image has a car
#
# The fifth image may be difficult to classify because it is another image with white arrows on a blue background.  The number and direction of the arrows is the only thing that makes the sign different from any of the other arrow signs is the number and direction of the arrows within the sign.
#
# ####2. Discuss the model's predictions on these new traffic signs and compare the results to predicting on the test set. At a minimum, discuss what the predictions were, the accuracy on these new predictions, and compare the accuracy to the accuracy on the test set (OPTIONAL: Discuss the results in more detail as described in the "Stand Out Suggestions" part of the rubric).
#
# Here are the results of the prediction:
#
# | Image                 |  Prediction         |
# |:---------------------:|:-------------------:|
# | Right Turn Ahead      | Right Turn Ahead    |
# | 30km/h Speed Limit    | General Caution     |
# | General Caution       | General Caution     |
# | Slippery Road         | Slippery Road       |
# | Roundabout Ahead      | Keep Right          |
#
#
#
#
# The model was able to correctly guess 3 of the 5 traffic signs, which gives an accuracy of 60%. This model needs some more improvement, but is a basic start to developing a fully reliable traffic sign classifier.
#
# ####3. Describe how certain the model is when predicting on each of the five new images by looking at the softmax probabilities for each prediction. Provide the top 5 softmax probabilities for each image along with the sign type of each probability. (OPTIONAL: as described in the "Stand Out Suggestions" part of the rubric, visualizations can also be provided such as bar charts)
#
# The first, third, and fourth images the classifier positively identified and had at least a 30% probability or higher.  The other two images it got wrong.  I want to look at the second image, which is the 30km/h speed limit sign.  It was 59% sure that it was a general caution sign.  I think that this might be caused by the fact that both are the same color.  The last sign, which was a roundabout ahead sign, the classifier only got an 11% probability on.  I think that this means that the classifier is probably over fitting the data because there are a lot of signs with blue backgrounds and white arrows.  I probably need to adjust the classifier to not overfit the data from training  by adding a dropout functionality to my classifier.  Refer to the below table for information on the probabilities obtained from the program.
#
# | Probability           |  Prediction         |
# |:---------------------:|:-------------------:|
# | 36.6%                 | Right Turn Ahead    |
# | 59.8%                 | General Caution     |
# | 68%                   | General Caution     |
# | 31%                   | Slippery Road       |
# | 11%                   | Keep Right          |
